# %%
def dfs(depth):
    if depth == M:
        s = ' '.join(map(str, li))
        if s not in d:
            d[s] = 1
            print(s)
        return ;
    for i in range(N):
        if depth == 0 or li[-1] <= nums[i]:
            li.append(nums[i])
            dfs(depth+1)
            li.pop()

N, M = map(int, input().split())
nums = sorted(map(int, input().split()))
d = {}; li = []
dfs(0)
# Out:
# 3 1
# 4 4 2
# 2
# 4

# %%
N, M = map(int, input().split())
nums = sorted(map(int, input().split()))
d = {}; li = []
dfs(0)
# Out:
# 4 2
# 9 7 9 1
# 1 1
# 1 7
# 1 9
# 7 7
# 7 9
# 9 9

# %%
N, M = map(int, input().split())
nums = sorted(map(int, input().split()))
d = {}; li = []
dfs(0)
# Out:
# 4 4
# 1 1 2 2
# 1 1 1 1
# 1 1 1 2
# 1 1 2 2
# 1 2 2 2
# 2 2 2 2
