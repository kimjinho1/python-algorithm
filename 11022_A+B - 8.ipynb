# %%
for i in range(int(input())):
    n1, n2 = map(int, input().split())
    print("Case #{0}: {1} + {2} = {3}".format(i+1, n1, n2, n1+n2))
# Out:
# 5
# 1 1
# Case #1: 1 + 1 = 2
# 2 3
# Case #2: 2 + 3 = 5
# 3 4
# Case #3: 3 + 4 = 7
# 9 8
# Case #4: 9 + 8 = 17
# 5 2
# Case #5: 5 + 2 = 7

# %% [markdown]
# #
