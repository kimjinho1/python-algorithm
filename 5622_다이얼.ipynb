# %%
s = ['abc','def','ghi','jkl','mno','pqrs','tuv','wxyz']
a = input().lower()
res = 0
for j in range(len(a)):
    for i in s:
        if a[j] in i:
            res += s.index(i)+3
print(res)
# Out:
# UNUCIC
# 36
