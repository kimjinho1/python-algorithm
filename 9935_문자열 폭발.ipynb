# %%
w = input()
boom = input()
while boom in w:
    w = w.replace(boom, '')
print(w) if len(w) else print('FRULA')
# Out:
# 12ab112ab2ab
# 12ab
# FRULA

# %%
mirkovC4nizCC44
C4

# %%
12ab112ab2ab
12ab
